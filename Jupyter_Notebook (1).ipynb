# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Claudia Cuevas**   Data Scientist

# %% [markdown]
# *I am interested in Data Science because I want to learn coding and how data shapes our life*

# %% [markdown]
# ### The answer to (3*7) is below

# %%
3*7
# Out:
# 21

# %% [markdown]
# ![Kelly Pup.jpg](attachment:f2f7bba9-c513-45b8-94de-5282b5792adc.jpg "Kelly Pup")
# ***
# >My name is Kelly
# >* I am 3 months old
